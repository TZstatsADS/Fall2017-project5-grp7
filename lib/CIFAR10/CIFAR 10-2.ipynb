# %% [markdown]
# ##### inpu_data.py

# %%
import tensorflow as tf
import numpy as np
import os

# %%
# file directory
def get_files(file_dir):
    # return random labels

    cats = []
    label_cats = []
    dogs = []
    label_dogs = []
    for file in os.listdir(file_dir):
        name = file.split(sep='.')
        if name[0] == 'cat':
            cats.append(file_dir + file)
            label_cats.append(0)
        else:
            dogs.append(file_dir + file)
            label_dogs.append(1)
    print("There are %d cats\nThere are %d dogs" % (len(cats), len(dogs)))

    # random.shuffle
    image_list = np.hstack((cats, dogs))
    label_list = np.hstack((label_cats, label_dogs))
    temp = np.array([image_list, label_list])
    temp = temp.transpose()
    np.random.shuffle(temp)

    image_list = list(temp[:, 0])
    label_list = list(temp[:, 1])
    label_list = [int(i) for i in label_list]

    return image_list, label_list

# %%
# generate batches of same size
def get_batch(image, label, image_W, image_H, batch_size, capacity):
    # transfer python.list to tensorflow
    image = tf.cast(image, tf.string)
    label = tf.cast(label, tf.int32)

    # generate queue
    input_queue = tf.train.slice_input_producer([image, label])

    image_contents = tf.read_file(input_queue[0])
    label = input_queue[1]
    image = tf.image.decode_jpeg(image_contents, channels=3)

    # resize image to same size
    image = tf.image.resize_images(image, [image_H, image_W], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    image = tf.cast(image, tf.float32)
    image_batch, label_batch = tf.train.batch([image, label],
                                              batch_size=batch_size,
                                              num_threads=64,
                                              capacity=capacity)
    
    return image_batch, label_batch

# %% [markdown]
# ##### Model.py

# %%
import tensorflow as tf

def inference(images, batch_size, n_classes):
    # conv1, shape = [kernel_size, kernel_size, channels, kernel_numbers]
    with tf.variable_scope("conv1") as scope:
        weights = tf.get_variable("weights",
                                  shape=[3, 3, 3, 16],
                                  dtype=tf.float32,
                                  initializer=tf.truncated_normal_initializer(stddev=0.1, dtype=tf.float32))
        biases = tf.get_variable("biases",
                                 shape=[16],
                                 dtype=tf.float32,
                                 initializer=tf.constant_initializer(0.1))
        conv = tf.nn.conv2d(images, weights, strides=[1, 1, 1, 1], padding="SAME")
        pre_activation = tf.nn.bias_add(conv, biases)
        conv1 = tf.nn.relu(pre_activation, name="conv1")

    # pool1 && norm1
    with tf.variable_scope("pooling1_lrn") as scope:
        pool1 = tf.nn.max_pool(conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1],
                               padding="SAME", name="pooling1")
        norm1 = tf.nn.lrn(pool1, depth_radius=4, bias=1.0, alpha=0.001/9.0,
                          beta=0.75, name='norm1')

    # conv2
    with tf.variable_scope("conv2") as scope:
        weights = tf.get_variable("weights",
                                  shape=[3, 3, 16, 16],
                                  dtype=tf.float32,
                                  initializer=tf.truncated_normal_initializer(stddev=0.1, dtype=tf.float32))
        biases = tf.get_variable("biases",
                                 shape=[16],
                                 dtype=tf.float32,
                                 initializer=tf.constant_initializer(0.1))
        conv = tf.nn.conv2d(norm1, weights, strides=[1, 1, 1, 1], padding="SAME")
        pre_activation = tf.nn.bias_add(conv, biases)
        conv2 = tf.nn.relu(pre_activation, name="conv2")

    # pool2 && norm2
    with tf.variable_scope("pooling2_lrn") as scope:
        pool2 = tf.nn.max_pool(conv2, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1],
                               padding="SAME", name="pooling2")
        norm2 = tf.nn.lrn(pool2, depth_radius=4, bias=1.0, alpha=0.001/9.0,
                          beta=0.75, name='norm2')

    # full-connect1
    with tf.variable_scope("fc1") as scope:
        reshape = tf.reshape(norm2, shape=[batch_size, -1])
        dim = reshape.get_shape()[1].value
        weights = tf.get_variable("weights",
                                  shape=[dim, 128],
                                  dtype=tf.float32,
                                  initializer=tf.truncated_normal_initializer(stddev=0.005, dtype=tf.float32))
        biases = tf.get_variable("biases",
                                 shape=[128],
                                 dtype=tf.float32,
                                 initializer=tf.constant_initializer(0.1))
        fc1 = tf.nn.relu(tf.matmul(reshape, weights) + biases, name="fc1")

    # full_connect2
    with tf.variable_scope("fc2") as scope:
        weights = tf.get_variable("weights",
                                  shape=[128, 128],
                                  dtype=tf.float32,
                                  initializer=tf.truncated_normal_initializer(stddev=0.005, dtype=tf.float32))
        biases = tf.get_variable("biases",
                                 shape=[128],
                                 dtype=tf.float32,
                                 initializer=tf.constant_initializer(0.1))
        fc2 = tf.nn.relu(tf.matmul(fc1, weights) + biases, name="fc2")

    # softmax
    with tf.variable_scope("softmax_linear") as scope:
        weights = tf.get_variable("weights",
                                  shape=[128, n_classes],
                                  dtype=tf.float32,
                                  initializer=tf.truncated_normal_initializer(stddev=0.005, dtype=tf.float32))
        biases = tf.get_variable("biases",
                                 shape=[n_classes],
                                 dtype=tf.float32,
                                 initializer=tf.constant_initializer(0.1))
        softmax_linear = tf.add(tf.matmul(fc2, weights), biases, name="softmax_linear")
    return softmax_linear

# %%
def losses(logits, labels):
    with tf.variable_scope("loss") as scope:
        cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits,
                                                                       labels=labels, name="xentropy_per_example")
        loss = tf.reduce_mean(cross_entropy, name="loss")
        tf.summary.scalar(scope.name + "loss", loss)
    return loss


def training(loss, learning_rate):
    with tf.name_scope("optimizer"):
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        global_step = tf.Variable(0, name="global_step", trainable=False)
        train_op = optimizer.minimize(loss, global_step=global_step)
    return train_op


def evaluation(logits, labels):
    with tf.variable_scope("accuracy") as scope:
        correct = tf.nn.in_top_k(logits, labels, 1)
        correct = tf.cast(correct, tf.float16)
        accuracy = tf.reduce_mean(correct)
        tf.summary.scalar(scope.name + "accuracy", accuracy)
    return accuracy

# %% [markdown]
# ##### training.py

# %%
N_CLASSES = 2
IMG_W=208
IMG_H=208
BATCH_SIZE=16 #32
CAPACITY=2000
MAX_STEP=15000  #MAX_STEP>10k
learning_rate=0.0001 #learning_rate<0.0001

def run_training():
    train_dir = 'train\\'
    logs_train_dir = 'logs_train\\'
    train, train_label = get_files(train_dir)
    train_batch, train_label_batch = get_batch(train, train_label,
                                                IMG_W, IMG_H,
                                                BATCH_SIZE, CAPACITY)
    train_logits=inference(train_batch,BATCH_SIZE,N_CLASSES)
    train_loss=losses(train_logits, train_label_batch)
    train_op=training(train_loss, learning_rate)
    train_acc=evaluation(train_logits,train_label_batch)
    
    
    sess=tf.Session()
    sess.run(tf.global_variables_initializer())

    summary_op=tf.summary.merge_all()
    train_writer=tf.summary.FileWriter(logs_train_dir, sess.graph)
    saver=tf.train.Saver()

    coord=tf.train.Coordinator()
    threads=tf.train.start_queue_runners(sess=sess, coord=coord)

    try:
        
        for step in np.arange(MAX_STEP):
            if coord.should_stop():
                    break
            _, tra_loss, tra_acc, tra_log = sess.run([train_op, train_loss, train_acc, train_logits])

            if step % 50 == 0:
                print('Step %d, train loss = %.2f, train accuracy= %.2f%%' %(step, tra_loss, tra_acc*100))
                print(tra_log)
                summary_str=sess.run(summary_op)
                train_writer.add_summary(summary_str, step)
                
            if step % 2000 == 0 or (step+1)==MAX_STEP:
                checkpoint_path=os.path.join(logs_train_dir,'model.ckpt')
                saver.save(sess, checkpoint_path, global_step =step)
    except tf.errors.OutOfRangeError:
        print('Done training -- epoch limit reached')
    finally:
        coord.request_stop()
    coord.join(threads)
    sess.close()

# %%
# run model
run_training()

# %%
# test file directory
def get_files2(file_dir):
    images = []
    for file in os.listdir(file_dir):
        name = file.split(sep='.')
        images.append(file_dir + file)
    print("There are %d images" % (len(images)))

    return images

# %%
from PIL import Image
import matplotlib.pyplot as plt

def get_one_image(train):
    #Not actually used in evaluation
    #Randomly pick one image from training data
    #Return: ndarray
    
    n = len(train)
    ind = np.random.randint(0, n)
    img_dir = train[ind]
    
    image = Image.open(img_dir)
    plt.imshow(image)
    plt.show()
    
    image = image.resize([208, 208])
    image = np.array(image)
    return image

def get_one_image2(test, n, image_plot=False):
    #pick n-th image from testing data
    #Return: ndarray
    
    img_dir = test[n]
    
    image = Image.open(img_dir)
    
    if image_plot:
        plt.imshow(image)
        plt.show()
    
    image = image.resize([208, 208])
    image = np.array(image)
    return image

def evaluate_one_image(n,  image_plot=False):
    #Test one image against the saved models and parameters
    # you need to change the directories to yours.
    
    test_dir = 'test\\'
    test= get_files2(test_dir)
    image_array = get_one_image2(test, n, image_plot)
    
    with tf.Graph().as_default():
        BATCH_SIZE = 1
        N_CLASSES = 2
        
        image = tf.cast(image_array, tf.float32)
        image = tf.reshape(image, [1, 208, 208, 3])
        logit = inference(image, BATCH_SIZE, N_CLASSES)
        
        logit = tf.nn.softmax(logit)
        
        x = tf.placeholder(tf.float32, shape=[208, 208, 3])
        
        #you need to change the directories to yours.
        
        logs_train_dir = 'logs_train\\' 
                       
        saver = tf.train.Saver()
        
        with tf.Session() as sess:
            
            print("Reading checkpoints...")
            ckpt = tf.train.get_checkpoint_state(logs_train_dir)
            if ckpt and ckpt.model_checkpoint_path:
                global_step = ckpt.model_checkpoint_path.split('/')[-1].split('-')[-1]
                saver.restore(sess, ckpt.model_checkpoint_path)
                print('Loading success, global_step is %s' % global_step)
            else:
                print('No checkpoint file found')
            
            prediction = sess.run(logit, feed_dict={x: image_array})
            print(prediction)
            return(prediction)
            max_index = np.argmax(prediction)
            if max_index==0:
                print('This is a cat with possibility %.6f \n' %prediction[:, 0])
                
            else:
                print('This is a dog with possibility %.6f \n' %prediction[:, 1])

# %%
cifar10_results=[]

for i in range(12500):  
    print('\n-----------------------')
    print(i)
    cifar10_results.append(evaluate_one_image(i, image_plot=False))

print(cifar10_results)
# Out:
# -----------------------
# 0
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99984741e-01   1.52075354e-05]]
#
# -----------------------
# 1
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99867201e-01   1.32744128e-04]]
#
# -----------------------
# 2
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99996901e-01   3.07063647e-06]]
#
# -----------------------
# 3
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.05595549e-11   1.00000000e+00]]
#
# -----------------------
# 4
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00152434  0.99847561]]
#
# -----------------------
# 5
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99218106e-01   7.81878131e-04]]
#
# -----------------------
# 6
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99841452e-01   1.58546231e-04]]
#
# -----------------------
# 7
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  6.01640293e-10   1.00000000e+00]]
#
# -----------------------
# 8
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00135104  0.99864894]]
#
# -----------------------
# 9
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99992609e-01   7.44302633e-06]]
#
# -----------------------
# 10
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99998927e-01   1.07802555e-06]]
#
# -----------------------
# 11
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   6.12750475e-12]]
#
# -----------------------
# 12
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99903560e-01   9.64030987e-05]]
#
# -----------------------
# 13
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.96469235  0.03530757]]
#
# -----------------------
# 14
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99892116e-01   1.07830521e-04]]
#
# -----------------------
# 15
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  8.61700357e-07   9.99999166e-01]]
#
# -----------------------
# 16
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.07393569e-08   1.00000000e+00]]
#
# -----------------------
# 17
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99641812  0.00358183]]
#
# -----------------------
# 18
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00170476  0.99829525]]
#
# -----------------------
# 19
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999762e-01   2.84851239e-07]]
#
# -----------------------
# 20
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00471156  0.99528837]]
#
# -----------------------
# 21
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.34728070e-05   9.99986529e-01]]
#
# -----------------------
# 22
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   3.35215644e-12]]
#
# -----------------------
# 23
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99881989  0.00118011]]
#
# -----------------------
# 24
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   7.58437150e-13]]
#
# -----------------------
# 25
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  8.12803478e-07   9.99999166e-01]]
#
# -----------------------
# 26
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99969244e-01   3.07709015e-05]]
#
# -----------------------
# 27
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.9910273   0.00897272]]
#
# -----------------------
# 28
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.73003883e-04   9.99726951e-01]]
#
# -----------------------
# 29
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.20915464e-08   1.00000000e+00]]
#
# -----------------------
# 30
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.05143226e-04   9.99894857e-01]]
#
# -----------------------
# 31
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00779112  0.99220884]]
#
# -----------------------
# 32
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.72115457  0.2788454 ]]
#
# -----------------------
# 33
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.78797908e-08   1.00000000e+00]]
#
# -----------------------
# 34
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999762e-01   2.36876247e-07]]
#
# -----------------------
# 35
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.42400116e-08   1.00000000e+00]]
#
# -----------------------
# 36
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99814570e-01   1.85487675e-04]]
#
# -----------------------
# 37
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.44406273e-13   1.00000000e+00]]
#
# -----------------------
# 38
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.01387687  0.98612309]]
#
# -----------------------
# 39
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  6.61838974e-04   9.99338090e-01]]
#
# -----------------------
# 40
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.02712689  0.97287309]]
#
# -----------------------
# 41
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.01247128  0.98752868]]
#
# -----------------------
# 42
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00530661  0.99469334]]
#
# -----------------------
# 43
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.04621857e-13   1.00000000e+00]]
#
# -----------------------
# 44
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.95521009  0.04478991]]
#
# -----------------------
# 45
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.90901011  0.09098991]]
#
# -----------------------
# 46
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.75818004e-09   1.00000000e+00]]
#
# -----------------------
# 47
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  6.27126573e-10   1.00000000e+00]]
#
# -----------------------
# 48
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00293272  0.99706727]]
#
# -----------------------
# 49
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.61089122e-08   1.00000000e+00]]
#
# -----------------------
# 50
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.73135547e-07   9.99999881e-01]]
#
# -----------------------
# 51
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.02140086e-06   9.99998927e-01]]
#
# -----------------------
# 52
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99953747e-01   4.62678872e-05]]
#
# -----------------------
# 53
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.9981851   0.00181485]]
#
# -----------------------
# 54
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.42566758e-09   1.00000000e+00]]
#
# -----------------------
# 55
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.08494091e-05   9.99969125e-01]]
#
# -----------------------
# 56
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.14512227e-09   1.00000000e+00]]
#
# -----------------------
# 57
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99845266e-01   1.54692549e-04]]
#
# -----------------------
# 58
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   1.93918703e-09]]
#
# -----------------------
# 59
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.95985293  0.04014707]]
#
# -----------------------
# 60
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   5.94468261e-08]]
#
# -----------------------
# 61
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.0015459   0.99845409]]
#
# -----------------------
# 62
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.75569303e-04   9.99024391e-01]]
#
# -----------------------
# 63
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99551207  0.00448788]]
#
# -----------------------
# 64
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99995828e-01   4.14292617e-06]]
#
# -----------------------
# 65
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.92325567e-04   9.99707639e-01]]
#
# -----------------------
# 66
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99996781e-01   3.19254832e-06]]
#
# -----------------------
# 67
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.62390578  0.37609416]]
#
# -----------------------
# 68
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.32766853e-06   9.99994636e-01]]
#
# -----------------------
# 69
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.10810435e-06   9.99997854e-01]]
#
# -----------------------
# 70
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.04521199e-07   9.99999285e-01]]
#
# -----------------------
# 71
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99989867e-01   1.01263495e-05]]
#
# -----------------------
# 72
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.0448292   0.95517081]]
#
# -----------------------
# 73
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.97607011  0.02392988]]
#
# -----------------------
# 74
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99743879e-01   2.56119733e-04]]
#
# -----------------------
# 75
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   2.83111365e-08]]
#
# -----------------------
# 76
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99910593e-01   8.93596443e-05]]
#
# -----------------------
# 77
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   1.38990805e-10]]
#
# -----------------------
# 78
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99697208e-01   3.02781962e-04]]
#
# -----------------------
# 79
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99994278e-01   5.76624234e-06]]
#
# -----------------------
# 80
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.87734832e-12   1.00000000e+00]]
#
# -----------------------
# 81
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99997377e-01   2.62996241e-06]]
#
# -----------------------
# 82
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   3.55254990e-08]]
#
# -----------------------
# 83
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999762e-01   2.13730630e-07]]
#
# -----------------------
# 84
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.87093756e-05   9.99981284e-01]]
#
# -----------------------
# 85
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.88044568e-04   9.99711931e-01]]
#
# -----------------------
# 86
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.82187027  0.17812975]]
#
# -----------------------
# 87
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.68209207  0.3179079 ]]
#
# -----------------------
# 88
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99860287e-01   1.39746364e-04]]
#
# -----------------------
# 89
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.44913137e-04   9.99555051e-01]]
#
# -----------------------
# 90
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.94414306  0.05585695]]
#
# -----------------------
# 91
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.19936631e-04   9.99880075e-01]]
#
# -----------------------
# 92
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00535069  0.99464935]]
#
# -----------------------
# 93
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.96376473  0.03623529]]
#
# -----------------------
# 94
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.79468115e-04   9.99520540e-01]]
#
# -----------------------
# 95
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.01114101  0.98885906]]
#
# -----------------------
# 96
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.20065362e-06   9.99995828e-01]]
#
# -----------------------
# 97
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00683734  0.99316263]]
#
# -----------------------
# 98
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.59899172e-06   9.99994397e-01]]
#
# -----------------------
# 99
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99272376  0.00727621]]
#
# -----------------------
# 100
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99971151e-01   2.88783722e-05]]
#
# -----------------------
# 101
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.7192114   0.28078857]]
#
# -----------------------
# 102
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.28631591e-05   9.99987125e-01]]
#
# -----------------------
# 103
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.80648959e-04   9.99219298e-01]]
#
# -----------------------
# 104
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99986529e-01   1.34648180e-05]]
#
# -----------------------
# 105
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  8.68539818e-09   1.00000000e+00]]
#
# -----------------------
# 106
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999642e-01   3.18881916e-07]]
#
# -----------------------
# 107
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.34435171e-11   1.00000000e+00]]
#
# -----------------------
# 108
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99799854  0.00200146]]
#
# -----------------------
# 109
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.32123173e-09   1.00000000e+00]]
#
# -----------------------
# 110
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.06701297e-04   9.99493241e-01]]
#
# -----------------------
# 111
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.39176910e-08   1.00000000e+00]]
#
# -----------------------
# 112
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.25424947e-06   9.99997735e-01]]
#
# -----------------------
# 113
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   2.30484645e-08]]
#
# -----------------------
# 114
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.08825392  0.91174603]]
#
# -----------------------
# 115
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.93507347e-05   9.99900699e-01]]
#
# -----------------------
# 116
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  8.62302477e-06   9.99991417e-01]]
#
# -----------------------
# 117
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99947429e-01   5.25585638e-05]]
#
# -----------------------
# 118
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   2.26231975e-08]]
#
# -----------------------
# 119
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.88091426e-09   1.00000000e+00]]
#
# -----------------------
# 120
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.01441537e-05   9.99989867e-01]]
#
# -----------------------
# 121
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.39089956e-09   1.00000000e+00]]
#
# -----------------------
# 122
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99395967e-01   6.04069151e-04]]
#
# -----------------------
# 123
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.94726497  0.05273505]]
#
# -----------------------
# 124
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99967694e-01   3.23250497e-05]]
#
# -----------------------
# 125
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99818146e-01   1.81933981e-04]]
#
# -----------------------
# 126
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.03025345e-10   1.00000000e+00]]
#
# -----------------------
# 127
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99977946e-01   2.20707079e-05]]
#
# -----------------------
# 128
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   2.18108509e-09]]
#
# -----------------------
# 129
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.38566060e-05   9.99966145e-01]]
#
# -----------------------
# 130
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99775112e-01   2.24943375e-04]]
#
# -----------------------
# 131
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.71806085  0.28193921]]
#
# -----------------------
# 132
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.27259205e-04   9.99272764e-01]]
#
# -----------------------
# 133
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   4.21594990e-08]]
#
# -----------------------
# 134
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00216276  0.99783725]]
#
# -----------------------
# 135
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99992013e-01   7.95541564e-06]]
#
# -----------------------
# 136
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99926805e-01   7.32453482e-05]]
#
# -----------------------
# 137
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99997854e-01   2.19735193e-06]]
#
# -----------------------
# 138
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   3.28497620e-08]]
#
# -----------------------
# 139
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.96201253  0.03798742]]
#
# -----------------------
# 140
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99981046e-01   1.89938928e-05]]
#
# -----------------------
# 141
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.25146110e-10   1.00000000e+00]]
#
# -----------------------
# 142
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99959826e-01   4.01587495e-05]]
#
# -----------------------
# 143
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99998331e-01   1.65089739e-06]]
#
# -----------------------
# 144
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  8.58692943e-07   9.99999166e-01]]
#
# -----------------------
# 145
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99960065e-01   3.99544952e-05]]
#
# -----------------------
# 146
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.21082245  0.78917748]]
#
# -----------------------
# 147
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99015862  0.00984132]]
#
# -----------------------
# 148
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.29517877  0.70482123]]
#
# -----------------------
# 149
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.78386623  0.21613376]]
#
# -----------------------
# 150
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   3.12958015e-09]]
#
# -----------------------
# 151
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.63290882  0.36709121]]
#
# -----------------------
# 152
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  6.97750220e-05   9.99930263e-01]]
#
# -----------------------
# 153
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.15600594e-06   9.99990821e-01]]
#
# -----------------------
# 154
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.58029595e-13   1.00000000e+00]]
#
# -----------------------
# 155
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99986291e-01   1.37541711e-05]]
#
# -----------------------
# 156
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  6.80559914e-11   1.00000000e+00]]
#
# -----------------------
# 157
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99166608e-01   8.33394646e-04]]
#
# -----------------------
# 158
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.61656341e-09   1.00000000e+00]]
#
# -----------------------
# 159
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99943733e-01   5.62600799e-05]]
#
# -----------------------
# 160
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.95178938  0.04821061]]
#
# -----------------------
# 161
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.18405779  0.81594223]]
#
# -----------------------
# 162
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.52947975e-05   9.99974728e-01]]
#
# -----------------------
# 163
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.01626451  0.98373556]]
#
# -----------------------
# 164
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99984622e-01   1.53931942e-05]]
#
# -----------------------
# 165
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.05802865e-12   1.00000000e+00]]
#
# -----------------------
# 166
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.39792935e-04   9.99760211e-01]]
#
# -----------------------
# 167
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.03238916e-05   9.99949694e-01]]
#
# -----------------------
# 168
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999881e-01   1.55224043e-07]]
#
# -----------------------
# 169
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   3.46074835e-09]]
#
# -----------------------
# 170
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.04071219  0.95928776]]
#
# -----------------------
# 171
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.98829508  0.01170493]]
#
# -----------------------
# 172
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999523e-01   5.32106071e-07]]
#
# -----------------------
# 173
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.14170184e-04   9.99785841e-01]]
#
# -----------------------
# 174
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   2.46670027e-08]]
#
# -----------------------
# 175
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99929905e-01   7.01433528e-05]]
#
# -----------------------
# 176
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999762e-01   2.39217258e-07]]
#
# -----------------------
# 177
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.23171383  0.76828617]]
#
# -----------------------
# 178
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00965024  0.99034977]]
#
# -----------------------
# 179
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.54903585  0.45096415]]
#
# -----------------------
# 180
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.19287863e-04   9.99880672e-01]]
#
# -----------------------
# 181
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99389648e-01   6.10293529e-04]]
#
# -----------------------
# 182
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   2.11456896e-09]]
#
# -----------------------
# 183
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.67084079e-06   9.99997377e-01]]
#
# -----------------------
# 184
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.06327816e-09   1.00000000e+00]]
#
# -----------------------
# 185
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.43481338  0.56518662]]
#
# -----------------------
# 186
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  8.28799998e-08   9.99999881e-01]]
#
# -----------------------
# 187
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  6.42630615e-10   1.00000000e+00]]
#
# -----------------------
# 188
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.67496457e-14   1.00000000e+00]]
#
# -----------------------
# 189
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.9983182   0.00168186]]
#
# -----------------------
# 190
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.57616230e-05   9.99974251e-01]]
#
# -----------------------
# 191
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.55959159  0.44040847]]
#
# -----------------------
# 192
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99992967e-01   7.06704122e-06]]
#
# -----------------------
# 193
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   1.15007097e-08]]
#
# -----------------------
# 194
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.68746209  0.31253788]]
#
# -----------------------
# 195
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.06032338  0.93967664]]
#
# -----------------------
# 196
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.27323017  0.72676986]]
#
# -----------------------
# 197
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.0016296   0.99837047]]
#
# -----------------------
# 198
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.69028449  0.30971545]]
#
# -----------------------
# 199
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.10981124e-07   9.99999523e-01]]
#
# -----------------------
# 200
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.49089637  0.50910366]]
#
# -----------------------
# 201
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.58701713e-04   9.99641299e-01]]
#
# -----------------------
# 202
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.07373289e-05   9.99989271e-01]]
#
# -----------------------
# 203
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99999762e-01   2.06221699e-07]]
#
# -----------------------
# 204
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.71462888  0.28537115]]
#
# -----------------------
# 205
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   6.86241197e-09]]
#
# -----------------------
# 206
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.24829312e-05   9.99987483e-01]]
#
# -----------------------
# 207
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99995589e-01   4.41381962e-06]]
#
# -----------------------
# 208
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.86708265e-05   9.99941349e-01]]
#
# -----------------------
# 209
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.02415925e-06   9.99998927e-01]]
#
# -----------------------
# 210
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.04893124e-05   9.99989510e-01]]
#
# -----------------------
# 211
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00412513  0.99587494]]
#
# -----------------------
# 212
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  6.17529569e-11   1.00000000e+00]]
#
# -----------------------
# 213
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.17848634e-14   1.00000000e+00]]
#
# -----------------------
# 214
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.01636218e-07   9.99999881e-01]]
#
# -----------------------
# 215
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   1.57368252e-08]]
#
# -----------------------
# 216
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.95466828  0.04533174]]
#
# -----------------------
# 217
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.87966365  0.12033637]]
#
# -----------------------
# 218
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   1.13551280e-12]]
#
# -----------------------
# 219
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.09763788  0.90236211]]
#
# -----------------------
# 220
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# ...
# Loading success, global_step is 14999
# [[ 0.83294737  0.16705261]]
#
# -----------------------
# 7437
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.44649224e-05   9.99925494e-01]]
#
# -----------------------
# 7438
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99231577e-01   7.68439786e-04]]
#
# -----------------------
# 7439
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  4.74099721e-07   9.99999523e-01]]
#
# -----------------------
# 7440
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00322722  0.99677271]]
#
# -----------------------
# 7441
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.86256325  0.13743673]]
#
# -----------------------
# 7442
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.01097841e-12   1.00000000e+00]]
#
# -----------------------
# 7443
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.97140074  0.02859923]]
#
# -----------------------
# 7444
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99998569e-01   1.46570449e-06]]
#
# -----------------------
# 7445
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.24645119e-05   9.99977589e-01]]
#
# -----------------------
# 7446
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.14107887e-09   1.00000000e+00]]
#
# -----------------------
# 7447
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.69918905e-14   1.00000000e+00]]
#
# -----------------------
# 7448
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.94969207  0.05030794]]
#
# -----------------------
# 7449
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   1.03257936e-09]]
#
# -----------------------
# 7450
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   8.97734526e-11]]
#
# -----------------------
# 7451
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.98197526  0.01802478]]
#
# -----------------------
# 7452
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  5.29477875e-05   9.99947071e-01]]
#
# -----------------------
# 7453
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.44351584  0.55648416]]
#
# -----------------------
# 7454
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  8.84781548e-05   9.99911547e-01]]
#
# -----------------------
# 7455
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00320091  0.99679911]]
#
# -----------------------
# 7456
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.04368119e-08   9.99999881e-01]]
#
# -----------------------
# 7457
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99402952  0.00597051]]
#
# -----------------------
# 7458
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.01458028  0.98541969]]
#
# -----------------------
# 7459
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.57737207  0.42262787]]
#
# -----------------------
# 7460
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.30507493  0.69492507]]
#
# -----------------------
# 7461
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.04461867  0.95538127]]
#
# -----------------------
# 7462
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00936898  0.99063104]]
#
# -----------------------
# 7463
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.9987601   0.00123986]]
#
# -----------------------
# 7464
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99824107e-01   1.75971960e-04]]
#
# -----------------------
# 7465
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.63815935e-06   9.99998331e-01]]
#
# -----------------------
# 7466
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.93320483e-07   9.99999762e-01]]
#
# -----------------------
# 7467
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00392834  0.9960717 ]]
#
# -----------------------
# 7468
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.32588914  0.67411083]]
#
# -----------------------
# 7469
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00143892  0.99856108]]
#
# -----------------------
# 7470
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.95096016  0.04903986]]
#
# -----------------------
# 7471
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.46192533  0.53807467]]
#
# -----------------------
# 7472
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99804676  0.00195319]]
#
# -----------------------
# 7473
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   5.19231793e-12]]
#
# -----------------------
# 7474
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99414325e-01   5.85710746e-04]]
#
# -----------------------
# 7475
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.39233118  0.60766882]]
#
# -----------------------
# 7476
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.00739504  0.99260497]]
#
# -----------------------
# 7477
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.72363599e-04   9.99727666e-01]]
#
# -----------------------
# 7478
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.36200157e-07   9.99999881e-01]]
#
# -----------------------
# 7479
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99063790e-01   9.36232915e-04]]
#
# -----------------------
# 7480
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99992967e-01   7.03320165e-06]]
#
# -----------------------
# 7481
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  2.27357032e-05   9.99977231e-01]]
#
# -----------------------
# 7482
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99778372  0.00221631]]
#
# -----------------------
# 7483
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.96258944  0.03741054]]
#
# -----------------------
# 7484
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  7.28672720e-04   9.99271333e-01]]
#
# -----------------------
# 7485
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.50308551e-06   9.99996543e-01]]
#
# -----------------------
# 7486
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99819916  0.00180089]]
#
# -----------------------
# 7487
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.11212318e-08   1.00000000e+00]]
#
# -----------------------
# 7488
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.77022773  0.22977227]]
#
# -----------------------
# 7489
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.68892527  0.31107476]]
#
# -----------------------
# 7490
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99676228e-01   3.23810440e-04]]
#
# -----------------------
# 7491
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.03090596  0.96909404]]
#
# -----------------------
# 7492
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.83386450e-09   1.00000000e+00]]
#
# -----------------------
# 7493
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  3.41318490e-04   9.99658704e-01]]
#
# -----------------------
# 7494
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.10547046e-06   9.99998927e-01]]
#
# -----------------------
# 7495
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.22672938  0.77327061]]
#
# -----------------------
# 7496
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.23451418e-05   9.99987602e-01]]
#
# -----------------------
# 7497
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.01616642  0.98383361]]
#
# -----------------------
# 7498
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99546164  0.00453831]]
#
# -----------------------
# 7499
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99996424e-01   3.55242560e-06]]
#
# -----------------------
# 7500
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99490142e-01   5.09855396e-04]]
#
# -----------------------
# 7501
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99972820e-01   2.71784083e-05]]
#
# -----------------------
# 7502
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.88687646  0.11312348]]
#
# -----------------------
# 7503
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.99977350e-01   2.26637494e-05]]
#
# -----------------------
# 7504
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.70603132  0.29396874]]
#
# -----------------------
# 7505
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.94274074  0.05725921]]
#
# -----------------------
# 7506
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.00000000e+00   5.92962159e-08]]
#
# -----------------------
# 7507
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  9.97758238e-04   9.99002278e-01]]
#
# -----------------------
# 7508
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[  1.71972297e-05   9.99982834e-01]]
#
# -----------------------
# 7509
# There are 12500 images
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from logs_train\model.ckpt-14999
# Loading success, global_step is 14999
# [[ 0.99455833  0.00544172]]
#
# -----------------------
# 7510
# There are 12500 images
